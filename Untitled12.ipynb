# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham62025865/shubham1/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/sales_data.csv")

# %%
df.head()
# Out:
#          Date   Product  Sales_Amount  Profit  Quantity Region  Year
# 0  07-05-2023    Tablet       1136.47  140.04         3   West  2023
# 1  30-04-2023  Keyboard        934.92  102.03         2  South  2023
# 2  07-08-2023  Keyboard        318.55   54.22         3   East  2023
# 3  07-09-2023    Laptop       1083.18  289.52         4   West  2023
# 4  09-08-2023   Monitor       1711.39  194.05         3   East  2023

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          100 non-null    object
#  1   Product       100 non-null    object
#  2   Sales_Amount  100 non-null    float64
#  3   Profit        100 non-null    float64
#  4   Quantity      100 non-null    int64
#  5   Region        100 non-null    object
#  6   Year          100 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.6+ KB

# %%
df.shape
# Out:
# (100, 7)

# %%
df.isnull().sum()
# Out:
# Date            0
# Product         0
# Sales_Amount    0
# Profit          0
# Quantity        0
# Region          0
# Year            0
# dtype: int64

# %%
df=df.dropna(axis=1)

# %%
df.describe()
# Out:
#        Sales_Amount      Profit    Quantity    Year
# count    100.000000  100.000000  100.000000   100.0
# mean    1090.084600  213.377400    5.670000  2023.0
# std      541.347673  127.320785    3.178383     0.0
# min      107.100000   18.110000    1.000000  2023.0
# 25%      638.777500  112.255000    3.000000  2023.0
# 50%     1144.920000  194.475000    6.000000  2023.0
# 75%     1551.877500  312.957500    9.000000  2023.0
# max     1994.640000  506.290000   10.000000  2023.0

# %%
df["Sales_Amount"].value_counts()
# Out:
# Sales_Amount
# 1136.47    1
# 657.22     1
# 761.48     1
# 1416.71    1
# 1285.38    1
#           ..
# 1682.57    1
# 515.05     1
# 448.12     1
# 137.78     1
# 1643.21    1
# Name: count, Length: 100, dtype: int64

# %%
sns.countplot(df["Sales_Amount"],label="count")
# Out:
# <Axes: ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder_y=LabelEncoder()
df["Sales_Amount"]=LabelEncoder_y.fit_transform(df["Sales_Amount"])
df["Sales_Amount"].unique()
# Out:
# array([49, 41,  8, 46, 81,  9, 87, 73, 64, 60, 91, 42, 83, 97, 38, 84, 78,
#        59, 40, 54, 31, 39, 11, 14, 95, 47, 98,  2, 15, 19, 77, 10, 50, 33,
#         6, 28, 34,  4, 86, 74, 67, 17, 56, 72, 71, 85, 22, 93, 70, 37, 44,
#        13, 63, 92, 55, 51, 68, 30, 96, 89, 36,  7, 66, 26, 82,  0, 57, 21,
#        29, 24, 65, 62, 69, 32, 90, 16,  1, 27, 88, 48, 99, 12,  3, 79, 94,
#        18, 61, 43, 75, 53, 20, 52, 35, 25, 58, 45,  5, 80, 23, 76])

# %%
df.iloc[:,1]=LabelEncoder_y.fit_transform(df.iloc[:,1].values)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="Sales_Amount")
