# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham62025865/shubham1/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas Data **Frame**

# %% [markdown]
# Practice with nba data set for player **informations**

# %%
import pandas as pd
import numpy as np

# %%
df_nba=pd.read_csv("/content/nba (2).csv")
df_nba.head(10)
# df_nba = pd.read_excel("filepath")
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2   John Holland  Boston Celtics      30       SG   27  06-05     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# 5   Amir Johnson  Boston Celtics      90       PF   29  06-09     240
# 6  Jordan Mickey  Boston Celtics      55       PF   21  06-08     235
# 7   Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8   Terry Rozier  Boston Celtics      12       PG   22  06-02     190
# 9   Marcus Smart  Boston Celtics      36       PG   22  06-04     220
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
type(df_nba)
# Out:
# pandas.core.frame.DataFrame

# %%
df_nba.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
df_nba.shape
# Out:
# (457, 9)

# %%
df_nba.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df_nba.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 452  False  False   False     False  False   False   False    False   False
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
#
# [457 rows x 9 columns]

# %%
df_nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df_nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df_nba.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
df_nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0, ..., 180, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99, ..., 235, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30, ..., 205,
#         'Boston University', nan],
#        ...,
#        ['Raul Neto', 'Utah Jazz', 25, ..., 179, nan, 900000.0],
#        ['Tibor Pleiss', 'Utah Jazz', 21, ..., 256, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24, ..., 231, 'Kansas', 947276.0]],
#       dtype=object)

# %%
df_nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2   John Holland  Boston Celtics      30       SG   27  06-05     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df_nba.tail()
# Out:
#              Name       Team  Number Position  Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz      41       PF   20  06-10     234  Kentucky
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-03     203    Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-01     179       NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-03     256       NaN
# 456   Jeff Withey  Utah Jazz      24        C   26    7-0     231    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
df_nba.sample()
# Out:
#                Name          Team  Number Position  Age Height  Weight  \
# 123  Chase Budinger  Phoenix Suns      10       SF   28  06-07     209
#
#      College    Salary
# 123  Arizona  206192.0

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # sort **values**
#
# > Add blockquote

# %%
df_nba.sort_values(by=["Name"],ascending=False)
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32  06-11
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34  06-09
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21  06-05
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24  06-03
# 386  Wilson Chandler          Denver Nuggets      21       SF   29  06-08
# ..               ...                     ...     ...      ...  ...    ...
# 312       Al Horford           Atlanta Hawks      15        C   30  06-10
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25  06-10
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21  06-06
# 356     Aaron Gordon           Orlando Magic       0       PF   20  06-09
# 152     Aaron Brooks           Chicago Bulls       0       PG   31    6-0
#
#      Weight         College      Salary
# ...

# %%
df_nba.sort_values(by=["Age"],ascending=True)
# Out:
#                    Name                    Team  Number Position  Age Height  \
# 226       Rashad Vaughn         Milwaukee Bucks      20       SG   19  06-06
# 122        Devin Booker            Phoenix Suns       1       SG   19  06-06
# 40   Kristaps Porzingis         New York Knicks       6       PF   20  07-03
# 401          Tyus Jones  Minnesota Timberwolves       1       PG   20  06-02
# 427     Cliff Alexander  Portland Trail Blazers      34       PF   20  06-08
# ..                  ...                     ...     ...      ...  ...    ...
# 261        Vince Carter       Memphis Grizzlies      15       SG   39  06-06
# 102      Pablo Prigioni    Los Angeles Clippers       9       PG   39  06-03
# 298          Tim Duncan       San Antonio Spurs      21        C   40  06-11
# 400       Kevin Garnett  Minnesota Timberwolves      21       PF   40  06-11
# 304        Andre Miller       San Antonio Spurs      24       PG   40  06-03
#
#      Weight         College     Salary
# ...

# %%
df_nba.sort_values(by=["Salary"],ascending=False)
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers      24       SF   37  06-06
# 169     LeBron James     Cleveland Cavaliers      23       SF   31  06-08
# 33   Carmelo Anthony         New York Knicks       7       SF   32  06-08
# 251    Dwight Howard         Houston Rockets      12        C   30  06-11
# 339       Chris Bosh              Miami Heat       1       PF   32  06-11
# ..               ...                     ...     ...      ...  ...    ...
# 273   Alex Stepheson       Memphis Grizzlies      35       PF   28  06-10
# 350    Briante Weber              Miami Heat      12       PG   23  06-02
# 353    Dorell Wright              Miami Heat      11       SF   30  06-09
# 397     Axel Toupane          Denver Nuggets       6       SG   23  06-07
# 409       Greg Smith  Minnesota Timberwolves       4       PF   25  06-10
#
#      Weight                College      Salary
# ...

# %%
df_nba.sort_values(by = ["Team","Salary"])
# Out:
#                  Name                Team  Number Position  Age Height  \
# 317   Lamar Patterson       Atlanta Hawks      13       SG   24  06-05
# 316      Mike Muscala       Atlanta Hawks      31       PF   24  06-11
# 313    Kris Humphries       Atlanta Hawks      43       PF   31  06-09
# 322    Walter Tavares       Atlanta Hawks      22        C   24  07-03
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24  06-06
# ..                ...                 ...     ...      ...  ...    ...
# 369      Bradley Beal  Washington Wizards       3       SG   22  06-05
# 376   Markieff Morris  Washington Wizards       5       PF   26  06-10
# 373     Marcin Gortat  Washington Wizards      13        C   32  06-11
# 375      Nene Hilario  Washington Wizards      42        C   33  06-11
# 382         John Wall  Washington Wizards       2       PG   25  06-04
#
#      Weight     College      Salary
# 317     225  Pittsburgh    525093.0
# 316     240    Bucknell    947276.0
# ...

# %%
df_nba.sort_values(by=["Team","Salary"],ascending=False)
# Out:
#                  Name                Team  Number Position  Age Height  \
# 382         John Wall  Washington Wizards       2       PG   25  06-04
# 375      Nene Hilario  Washington Wizards      42        C   33  06-11
# 373     Marcin Gortat  Washington Wizards      13        C   32  06-11
# 376   Markieff Morris  Washington Wizards       5       PF   26  06-10
# 369      Bradley Beal  Washington Wizards       3       SG   22  06-05
# ..                ...                 ...     ...      ...  ...    ...
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24  06-06
# 313    Kris Humphries       Atlanta Hawks      43       PF   31  06-09
# 322    Walter Tavares       Atlanta Hawks      22        C   24  07-03
# 316      Mike Muscala       Atlanta Hawks      31       PF   24  06-11
# 317   Lamar Patterson       Atlanta Hawks      13       SG   24  06-05
#
#      Weight     College      Salary
# 382     195    Kentucky  15851950.0
# 375     250         NaN  13000000.0
# ...

# %% [markdown]
# # **value_count**

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_nba.Position.value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
df_nba["Position"].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
df_nba["Team"].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df_nba[["College","Team"]].value_counts()
# Out:
# College         Team
# Kentucky        Phoenix Suns              4
# North Carolina  Memphis Grizzlies         3
# Duke            Miami Heat                3
# UCLA            Memphis Grizzlies         3
# Kentucky        Sacramento Kings          3
#                                          ..
# Kansas          Philadelphia 76ers        1
#                 Oklahoma City Thunder     1
#                 Minnesota Timberwolves    1
#                 Los Angeles Lakers        1
# Xavier          San Antonio Spurs         1
# Name: count, Length: 336, dtype: int64

# %%
df_nba[["College","Team","Salary"]].value_counts()
# Out:
# College         Team                  Salary
# Kentucky        Phoenix Suns          13500000.0    2
# Alabama         Cleveland Cavaliers   2100000.0     1
# Oklahoma State  Memphis Grizzlies     5158539.0     1
# Pittsburgh      Atlanta Hawks         525093.0      1
# Penn State      New Orleans Pelicans  845059.0      1
#                                                    ..
# Kansas          Cleveland Cavaliers   1276000.0     1
#                 Brooklyn Nets         981348.0      1
#                 Atlanta Hawks         2854940.0     1
# Iowa State      New Orleans Pelicans  169883.0      1
# Xavier          San Antonio Spurs     1499187.0     1
# Name: count, Length: 363, dtype: int64

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_nba["Name"].unique()
# Out:
# array(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#        'Jonas Jerebko', 'Amir Johnson', 'Jordan Mickey', 'Kelly Olynyk',
#        'Terry Rozier', 'Marcus Smart', 'Jared Sullinger', 'Isaiah Thomas',
#        'Evan Turner', 'James Young', 'Tyler Zeller', 'Bojan Bogdanovic',
#        'Markel Brown', 'Wayne Ellington', 'Rondae Hollis-Jefferson',
#        'Jarrett Jack', 'Sergey Karasev', 'Sean Kilpatrick',
#        'Shane Larkin', 'Brook Lopez', 'Chris McCullough', 'Willie Reed',
#        'Thomas Robinson', 'Henry Sims', 'Donald Sloan', 'Thaddeus Young',
#        'Arron Afflalo', 'Lou Amundson', 'Thanasis Antetokounmpo',
#        'Carmelo Anthony', 'Jose Calderon', 'Cleanthony Early',
#        'Langston Galloway', 'Jerian Grant', 'Robin Lopez', "Kyle O'Quinn",
#        'Kristaps Porzingis', 'Kevin Seraphin', 'Lance Thomas',
#        'Sasha Vujacic', 'Derrick Williams', 'Tony Wroten', 'Elton Brand',
# ...

# %%
df_nba["Name"].nunique()
# Out:
# 457

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_nba[df_nba.Team=="Boston Celtics"]
# Out:
#                Name            Team  Number Position  Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1       Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2      John Holland  Boston Celtics      30       SG   27  06-05     205
# 3       R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# 5      Amir Johnson  Boston Celtics      90       PF   29  06-09     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21  06-08     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8      Terry Rozier  Boston Celtics      12       PG   22  06-02     190
# 9      Marcus Smart  Boston Celtics      36       PG   22  06-04     220
# 10  Jared Sullinger  Boston Celtics       7        C   24  06-09     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27  05-09     185
# ...

# %%
df_nba[df_nba.Name=="Avery Bradley"]
# Out:
#             Name            Team  Number Position  Age Height  Weight College  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-02     180   Texas
#
#       Salary
# 0  7730337.0

# %%
team_comb = df_nba.value_counts(["Team","College"]).reset_index()
team_comb[:50]
# Out:
#                       Team              College  count
# 0             Phoenix Suns             Kentucky      4
# 1        Memphis Grizzlies       North Carolina      3
# 2               Miami Heat                 Duke      3
# 3         Sacramento Kings             Kentucky      3
# 4       Washington Wizards               Kansas      3
# 5        Memphis Grizzlies                 UCLA      3
# 6       Philadelphia 76ers                 Duke      2
# 7   Minnesota Timberwolves             Kentucky      2
# 8   Minnesota Timberwolves                 UCLA      2
# 9    Oklahoma City Thunder             Kentucky      2
# 10       Charlotte Hornets          Connecticut      2
# 11       Charlotte Hornets             Kentucky      2
# 12       Charlotte Hornets       North Carolina      2
# 13          Indiana Pacers              Arizona      2
# 14  Portland Trail Blazers                 Duke      2
# 15        Dallas Mavericks              Florida      2
# ...

# %%
df_nba[df_nba["Team"] == "Boston Celtics"]
# Out:
#                Name            Team  Number Position  Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1       Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2      John Holland  Boston Celtics      30       SG   27  06-05     205
# 3       R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# 5      Amir Johnson  Boston Celtics      90       PF   29  06-09     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21  06-08     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8      Terry Rozier  Boston Celtics      12       PG   22  06-02     190
# 9      Marcus Smart  Boston Celtics      36       PG   22  06-04     220
# 10  Jared Sullinger  Boston Celtics       7        C   24  06-09     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27  05-09     185
# ...

# %%
df_nba[(df_nba["Age"]>=24)&(df_nba["Age"]<=26)]
# Out:
#                 Name            Team  Number Position  Age Height  Weight  \
# 0      Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1        Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 7       Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 10   Jared Sullinger  Boston Celtics       7        C   24  06-09     260
# 14      Tyler Zeller  Boston Celtics      44        C   26    7-0     253
# ..               ...             ...     ...      ...  ...    ...     ...
# 451    Chris Johnson       Utah Jazz      23       SF   26  06-06     206
# 453     Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454        Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455     Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456      Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#             College     Salary
# 0             Texas  7730337.0
# ...

# %%
temp_df = df_nba.copy()
temp_df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
temp_df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
temp_df["College"].fillna(value="Sityog",inplace=True)

# %%
temp_df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College      0
# Salary      11
# dtype: int64

# %%
df_nba.groupby("College")["Age"].min()
# Out:
# College
# Alabama             25
# Arizona             20
# Arizona State       26
# Arkansas            21
# Baylor              25
#                     ..
# Western Michigan    25
# Wichita State       25
# Wisconsin           22
# Wyoming             23
# Xavier              35
# Name: Age, Length: 118, dtype: int64
