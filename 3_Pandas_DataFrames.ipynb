# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham62025865/shubham1/blob/main/3_Pandas_DataFrames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas - `DataFrame`s
#
# Probably the most important data structure of pandas is the `DataFrame`. It's a tabular structure tightly integrated with `Series`.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <img width="700" src="https://user-images.githubusercontent.com/872296/38153492-72c032ca-3443-11e8-80f4-9de9060a5127.png" />
#
# Creating `DataFrame`s manually can be tedious. 99% of the time you'll be pulling the data from a Database, a csv file or the web. But still, you can create a DataFrame by specifying the columns and values:

# %%
pd.DataFrame({
    "Population" : [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    "GDP" : [1785387,2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075],
    "Surface" : [9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067],
      'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]

}, index = ['Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States'])
# Out:
#                 Population       GDP  Surface    HDI Continent
# Canada              35.467   1785387  9984670  0.913   America
# France              63.951   2833687   640679  0.888    Europe
# Germany             80.940   3874437   357114  0.916    Europe
# Italy               60.665   2167744   301336  0.873    Europe
# Japan              127.061   4602367   377930  0.891      Asia
# United Kingdom      64.511   2950039   242495  0.907    Europe
# United States      318.523  17348075  9525067  0.915   America

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %% [markdown]
# _(The `columns` attribute is optional. I'm using it to keep the same order as in the picture above)_

# %%
df1
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df1.loc[3]
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# Name: 3, dtype: object

# %%
df1.iloc[3]
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# Name: 3, dtype: object

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %% [markdown]
# `DataFrame`s also have indexes. As you can see in the "table" above, pandas has assigned a numeric, autoincremental index automatically to each "row" in our DataFrame. In our case, we know that each row represents a country, so we'll just reassign the index:

# %%
type("1")
# Out:
# str

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',
]

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
# Return an int representing the number of elements in this object.
# Return the number of rows if Series. Otherwise return the number of rows times number of columns if DataFrame.
df.size
# Out:
# 35

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.Population.sum()/7
# Out:
# 107.30257142857144

# %%
df.shape
# Out:
# (7, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
df.Population.median()
# Out:
# 64.511

# %%
type(df.Population)
# Out:
# pandas.core.series.Series

# %%
df.Population.sort_values(ascending = False)
# Out:
# United States     318.523
# Japan             127.061
# Germany            80.940
# United Kingdom     64.511
# France             63.951
# Italy              60.665
# Canada             35.467
# Name: Population, dtype: float64

# %%
(80.940 + 127.061)/2
# Out:
# 104.0005

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.Population.median()
# Out:
# 64.511

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %% [markdown]
# <img width="700" src="https://miro.medium.com/max/1720/1*JwIzwIA-EbinfbS20fw8hA.png" />
# <img width="700" src="" />

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.GDP
# Out:
# Canada             1785387
# France             2833687
# Germany            3874437
# Italy              2167744
# Japan              4602367
# United Kingdom     2950039
# United States     17348075
# Name: GDP, dtype: int64

# %%
df.HDI
# Out:
# Canada            0.913
# France            0.888
# Germany           0.916
# Italy             0.873
# Japan             0.891
# United Kingdom    0.907
# United States     0.915
# Name: HDI, dtype: float64

# %%
df['GDP']
# Out:
# Canada             1785387
# France             2833687
# Germany            3874437
# Italy              2167744
# Japan              4602367
# United Kingdom     2950039
# United States     17348075
# Name: GDP, dtype: int64

# %%
df["Population"]
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.Continent.value_counts()
# Out:
# Europe     4
# America    2
# Asia       1
# Name: Continent, dtype: int64

# %%
df.Continent.value_counts()
# Out:
# Europe     4
# America    2
# Asia       1
# Name: Continent, dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Indexing, Selection and Slicing
#
# Individual columns in the DataFrame can be selected with regular indexing. Each column is represented as a `Series`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.loc["Japan"]
# Out:
# Population      127.061
# GDP             4602367
# Surface Area     377930
# HDI               0.891
# Continent          Asia
# Name: Japan, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df.loc["Canada"]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df.Population
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
type(df['Population'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Note that the `index` of the returned Series is the same as the DataFrame one. And its `name` is the name of the column. If you're working on a notebook and want to see a more DataFrame-like format you can use the `to_frame` method:

# %%
df['Population'].to_frame()
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %% [markdown]
# Multiple columns can also be selected similarly to `numpy` and `Series`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.loc["Canada" : "Germany", "Population": "Surface Area"]
# Out:
#          Population      GDP  Surface Area
# Canada       35.467  1785387       9984670
# France       63.951  2833687        640679
# Germany      80.940  3874437        357114

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.iloc[0 : 3, 0: 3]
# Out:
#          Population      GDP  Surface Area
# Canada       35.467  1785387       9984670
# France       63.951  2833687        640679
# Germany      80.940  3874437        357114

# %%
df.loc[["Canada", "Germany", "France"], ["GDP", "HDI", "Surface Area"]]
# Out:
#              GDP    HDI  Surface Area
# Canada   1785387  0.913       9984670
# Germany  3874437  0.916        357114
# France   2833687  0.888        640679

# %%
df[["HDI", "Continent", "GDP"]]
# Out:
#                   HDI Continent       GDP
# Canada          0.913   America   1785387
# France          0.888    Europe   2833687
# Germany         0.916    Europe   3874437
# Italy           0.873    Europe   2167744
# Japan           0.891      Asia   4602367
# United Kingdom  0.907    Europe   2950039
# United States   0.915   America  17348075

# %%
column_list = ["Population", "GDP", "Surface Area"]
df[column_list]
# Out:
#                 Population       GDP  Surface Area
# Canada              35.467   1785387       9984670
# France              63.951   2833687        640679
# Germany             80.940   3874437        357114
# Italy               60.665   2167744        301336
# Japan              127.061   4602367        377930
# United Kingdom      64.511   2950039        242495
# United States      318.523  17348075       9525067

# %%
df[["Population", "GDP", "Surface Area"]]
# Out:
#                 Population       GDP  Surface Area
# Canada              35.467   1785387       9984670
# France              63.951   2833687        640679
# Germany             80.940   3874437        357114
# Italy               60.665   2167744        301336
# Japan              127.061   4602367        377930
# United Kingdom      64.511   2950039        242495
# United States      318.523  17348075       9525067

# %%
df["Population"]
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df[['Population', 'GDP', "HDI"]]
# Out:
#                 Population       GDP    HDI
# Canada              35.467   1785387  0.913
# France              63.951   2833687  0.888
# Germany             80.940   3874437  0.916
# Italy               60.665   2167744  0.873
# Japan              127.061   4602367  0.891
# United Kingdom      64.511   2950039  0.907
# United States      318.523  17348075  0.915

# %% [markdown]
# In this case, the result is another `DataFrame`. Slicing works differently, it acts at "row level", and can be counter intuitive:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.iloc[:,[0]]
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %%
df.loc[["Italy", "United Kingdom"]]
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# Italy               60.665  2167744        301336  0.873    Europe
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df.iloc[[3,5]]
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# Italy               60.665  2167744        301336  0.873    Europe
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %% [markdown]
# Row level selection works better with `loc` and `iloc` **which are recommended** over regular "direct slicing" (`df[:]`).
#
# `loc` selects rows matching the given index:

# %%
df.loc["Germany": "United Kingdom"]
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# Germany             80.940  3874437        357114  0.916    Europe
# Italy               60.665  2167744        301336  0.873    Europe
# Japan              127.061  4602367        377930  0.891      Asia
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df.iloc[2:5]
# Out:
# Empty DataFrame
# Columns: [Population, GDP, Surface Area, HDI, Continent]
# Index: []

# %%
df.loc['Italy']
# Out:
# Population       60.665
# GDP             2167744
# Surface Area     301336
# HDI               0.873
# Continent        Europe
# Name: Italy, dtype: object

# %%
df.loc['France': 'Italy']
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe

# %% [markdown]
# As a second "argument", you can pass the column(s) you'd like to select:

# %%
df.loc["France" : "Italy", ["Population", "HDI"]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.916
# Italy        60.665  0.873

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
s = "abcdefg"
s[3:0:-1]
# Out:
# 'dcb'

# %%
df.loc[ "Canada": "Japan" : -1]
# Out:
# Empty DataFrame
# Columns: [Population, GDP, Surface Area, HDI, Continent]
# Index: []

# %%
df.iloc[5:0:-1]
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# United Kingdom      64.511  2950039        242495  0.907    Europe
# Japan              127.061  4602367        377930  0.891      Asia
# Italy               60.665  2167744        301336  0.873    Europe
# Germany             80.940  3874437        357114  0.916    Europe
# France              63.951  2833687        640679  0.888    Europe

# %%
df.loc[: : -1, : : -1 ]
# Out:
#                Continent    HDI  Surface Area       GDP  Population
# United States    America  0.915       9525067  17348075     318.523
# United Kingdom    Europe  0.907        242495   2950039      64.511
# Japan               Asia  0.891        377930   4602367     127.061
# Italy             Europe  0.873        301336   2167744      60.665
# Germany           Europe  0.916        357114   3874437      80.940
# France            Europe  0.888        640679   2833687      63.951
# Canada           America  0.913       9984670   1785387      35.467

# %%
df
# Out:
#                 Population  GDP  Surface Area  HDI Continent
# Canada                 NaN  NaN           NaN  NaN       NaN
# France                 NaN  NaN           NaN  NaN       NaN
# Germany                NaN  NaN           NaN  NaN       NaN
# Italy                  NaN  NaN           NaN  NaN       NaN
# Japan                  NaN  NaN           NaN  NaN       NaN
# United Kingdom         NaN  NaN           NaN  NaN       NaN
# United States          NaN  NaN           NaN  NaN       NaN

# %%
df.loc["France":"Italy", "Population" : "HDI"]
# Out:
#          Population      GDP  Surface Area    HDI
# France       63.951  2833687        640679  0.888
# Germany      80.940  3874437        357114  0.916
# Italy        60.665  2167744        301336  0.873

# %%
df.loc['France': 'Italy', 'Population']
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: Population, dtype: float64

# %%
df.loc['France': 'Italy', ['Population', 'GDP']]
# Out:
#          Population      GDP
# France       63.951  2833687
# Germany      80.940  3874437
# Italy        60.665  2167744

# %% [markdown]
# `iloc` works with the (numeric) "position" of the index:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df.iloc[[0, 1, -1], [0,1,-1]]
# Out:
#                Population       GDP Continent
# Canada             35.467   1785387   America
# France             63.951   2833687    Europe
# United States     318.523  17348075   America

# %%
df.iloc[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.iloc[2: 5, [1,0,2]]
# Out:
#              GDP  Population  Surface Area
# Germany  3874437      80.940        357114
# Italy    2167744      60.665        301336
# Japan    4602367     127.061        377930

# %%
df.iloc[1:3, 4]
# Out:
# France     Europe
# Germany    Europe
# Name: Continent, dtype: object

# %%
df.iloc[1:3, [0, 3]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.916

# %%
df.iloc[1:3, 1:3]
# Out:
#              GDP  Surface Area
# France   2833687        640679
# Germany  3874437        357114

# %% [markdown]
# > **RECOMMENDED: Always use `loc` and `iloc` to reduce ambiguity, specially with `DataFrame`s with numeric indexes.**

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Conditional selection (boolean arrays)
#
# We saw conditional selection applied to `Series` and it'll work in the same way for `DataFrame`s. After all, a `DataFrame` is a collection of `Series`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
s = pd.Series([34,56,78,65,45,78])

# %%
s[s > 50]
# Out:
# 1    56
# 2    78
# 3    65
# 5    78
# dtype: int64

# %%
df.Population
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df.Population > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df[df.Population > 70]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
a= ["r","e", "s","t"]
a
# Out:
# ['r', 'e', 's', 't']

# %%
a[0:3]
# Out:
# ['r', 'e', 's']

# %%
a[::-1]
# Out:
# ['t', 's', 'e', 'r']

# %%
a[1:3:-1]
# Out:
# []

# %%
df.GDP[df.Population > 70]
# Out:
# Germany           3874437
# Japan             4602367
# United States    17348075
# Name: GDP, dtype: int64

# %%
df.Population > 75
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
mask = [True, False, True, False, False, True, True]
mask
# Out:
# [True, False, True, False, False, True, True]

# %%
df[mask]
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# Germany             80.940   3874437        357114  0.916    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df[df.Population > 100]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
df['Population'] > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df.loc[df['Population'] > 70]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.loc[df.Population > 70, ["Population", "GDP","Surface Area"]]
# Out:
#                Population       GDP  Surface Area
# Germany            80.940   3874437        357114
# Japan             127.061   4602367        377930
# United States     318.523  17348075       9525067

# %%
df.Population[df.Population > 70]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: Population, dtype: float64

# %%
df.loc[df.Population > 70, "Population" : "Surface Area"]
# Out:
#                Population       GDP  Surface Area
# Germany            80.940   3874437        357114
# Japan             127.061   4602367        377930
# United States     318.523  17348075       9525067

# %%
df[["Population", "GDP","Surface Area"]][df.Population > 70]
# Out:
#                Population       GDP  Surface Area
# Germany            80.940   3874437        357114
# Japan             127.061   4602367        377930
# United States     318.523  17348075       9525067

# %%
df[df.Population > 70]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %% [markdown]
# The boolean matching is done at Index level, so you can filter by any row, as long as it contains the right indexes. Column selection still works as expected:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.loc[(df.Population >60) & ((df.Continent == "Europe") | (df.Continent == "Asia")) , "GDP" : "Continent"]
# Out:
#                     GDP  Surface Area    HDI Continent
# France          2833687        640679  0.888    Europe
# Germany         3874437        357114  0.916    Europe
# Italy           2167744        301336  0.873    Europe
# Japan           4602367        377930  0.891      Asia
# United Kingdom  2950039        242495  0.907    Europe

# %%
df.loc[df['Population'] > 70, 'Population']
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: Population, dtype: float64

# %%
df.loc[df['Population'] > 70, ['Population', 'GDP']]
# Out:
#                Population       GDP
# Germany            80.940   3874437
# Japan             127.061   4602367
# United States     318.523  17348075

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Dropping stuff
#
# Opposed to the concept of selection, we have "dropping". Instead of pointing out which values you'd like to _select_ you could point which ones you'd like to `drop`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df_temp = df.copy()

# %%
df_temp
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df_temp.drop("Japan", inplace = True)

# %%
df_temp
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop("Canada")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop('Canada')
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df_temp
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df_temp = df_temp.drop(["Germany", "United States"])

# %%
df_temp
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# Canada              35.467  1785387       9984670  0.913   America
# France              63.951  2833687        640679  0.888    Europe
# Italy               60.665  2167744        301336  0.873    Europe
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df.drop(['Canada', 'Japan'])
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df_temp
# Out:
#                 Population      GDP  Surface Area    HDI Continent
# Canada              35.467  1785387       9984670  0.913   America
# France              63.951  2833687        640679  0.888    Europe
# Italy               60.665  2167744        301336  0.873    Europe
# United Kingdom      64.511  2950039        242495  0.907    Europe

# %%
df_temp.drop(columns = ["Population", "HDI"], inplace =True)

# %%
df_temp
# Out:
#                     GDP  Surface Area Continent
# Canada          1785387       9984670   America
# France          2833687        640679    Europe
# Italy           2167744        301336    Europe
# United Kingdom  2950039        242495    Europe

# %%
df_temp = df.copy()

# %%
df_temp
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df_temp.drop(index = ["Canada", "Germany", "Japan"], columns = ["GDP", "HDI"])
# Out:
#                 Population  Surface Area Continent
# France              63.951        640679    Europe
# Italy               60.665        301336    Europe
# United Kingdom      64.511        242495    Europe
# United States      318.523       9525067   America

# %%
df.drop(columns=['Population', 'HDI'])
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df_temp
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df_temp.drop(["GDP", "HDI"], axis = 1)
# Out:
#                 Population  Surface Area Continent
# Canada              35.467       9984670   America
# France              63.951        640679    Europe
# Germany             80.940        357114    Europe
# Italy               60.665        301336    Europe
# Japan              127.061        377930      Asia
# United Kingdom      64.511        242495    Europe
# United States      318.523       9525067   America

# %%
df.drop(['Italy', 'Canada'], axis=0)
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(['Population', 'HDI'], axis=1)
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(['Population', 'HDI'], axis='columns')
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(['Canada', 'Germany'], axis='index')
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# All these `drop` methods return a new `DataFrame`. If you'd like to modify it "in place", you can use the `inplace` attribute (there's an example below).

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Operations

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada             135.467   1785387       9984670  0.913   America
# France             163.951   2833687        640679  0.888    Europe
# Germany            180.940   3874437        357114  0.916    Europe
# Italy              160.665   2167744        301336  0.873    Europe
# Japan              227.061   4602367        377930  0.891      Asia
# United Kingdom     164.511   2950039        242495  0.907    Europe
# United States      418.523  17348075       9525067  0.915   America

# %%
df["Population"] = df["Population"] + 100

# %%
df["Population"] + 100
# Out:
# Canada            135.467
# France            163.951
# Germany           180.940
# Italy             160.665
# Japan             227.061
# United Kingdom    164.511
# United States     418.523
# Name: Population, dtype: float64

# %%
df[['Population', 'GDP']]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
df[['Population', 'GDP']] / 100
# Out:
#                 Population        GDP
# Canada             0.35467   17853.87
# France             0.63951   28336.87
# Germany            0.80940   38744.37
# Italy              0.60665   21677.44
# Japan              1.27061   46023.67
# United Kingdom     0.64511   29500.39
# United States      3.18523  173480.75

# %% [markdown]
# **Operations with Series** work at a column level, broadcasting down the rows.

# %%
crisis = pd.Series([-1000000, -0.3], index = ["GDP", "HDI"])

# %%
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
crisis = pd.Series([-1000000, -0.3], index=['GDP', 'HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']]
# Out:
#                      GDP    HDI
# Canada           1785387  0.913
# France           2833687  0.888
# Germany          3874437  0.916
# Italy            2167744  0.873
# Japan            4602367  0.891
# United Kingdom   2950039  0.907
# United States   17348075  0.915

# %%
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']] + crisis
# Out:
#                        GDP    HDI
# Canada            785387.0  0.613
# France           1833687.0  0.588
# Germany          2874437.0  0.616
# Italy            1167744.0  0.573
# Japan            3602367.0  0.591
# United Kingdom   1950039.0  0.607
# United States   16348075.0  0.615

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Modifying DataFrames
#
# It's simple and intuitive, You can add columns, or replace values for columns without issues:

# %% [markdown]
# ### Adding a new column

# %%
language = pd.Series(["French", "German", "Japanese"],
          index = ["France", "Germany", "Japan"])

# %%
language
# Out:
# France       French
# Germany      German
# Japan      Japanese
# dtype: object

# %%
df["Language"] = language

# %%
df["Language"] = language

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent  Language
# Canada             135.467   1785387       9984670  0.913   America       NaN
# France             163.951   2833687        640679  0.888    Europe    French
# Germany            180.940   3874437        357114  0.916    Europe    German
# Italy              160.665   2167744        301336  0.873    Europe       NaN
# Japan              227.061   4602367        377930  0.891      Asia  Japanese
# United Kingdom     164.511   2950039        242495  0.907    Europe       NaN
# United States      418.523  17348075       9525067  0.915   America       NaN

# %%
langs = pd.Series(
    ['French', 'German', 'Italian'],
    index=['France', 'Germany', 'Italy'],
    name='Language'
)

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: object

# %%
df['Language'] = langs

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387       9984670  0.913   America      NaN
# France              63.951   2833687        640679  0.888    Europe   French
# Germany             80.940   3874437        357114  0.916    Europe   German
# Italy               60.665   2167744        301336  0.873    Europe  Italian
# Japan              127.061   4602367        377930  0.891      Asia      NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe      NaN
# United States      318.523  17348075       9525067  0.915   America      NaN

# %% [markdown]
# ---
# ### Replacing values per column

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent  Language
# Canada             135.467   1785387       9984670  0.913   America       NaN
# France             163.951   2833687        640679  0.888    Europe    French
# Germany            180.940   3874437        357114  0.916    Europe    German
# Italy              160.665   2167744        301336  0.873    Europe       NaN
# Japan              227.061   4602367        377930  0.891      Asia  Japanese
# United Kingdom     164.511   2950039        242495  0.907    Europe       NaN
# United States      418.523  17348075       9525067  0.915   America       NaN

# %%
df["Language"] = "English"

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada             135.467   1785387       9984670  0.913   America  English
# France             163.951   2833687        640679  0.888    Europe  English
# Germany            180.940   3874437        357114  0.916    Europe  English
# Italy              160.665   2167744        301336  0.873    Europe  English
# Japan              227.061   4602367        377930  0.891      Asia  English
# United Kingdom     164.511   2950039        242495  0.907    Europe  English
# United States      418.523  17348075       9525067  0.915   America  English

# %%
df['Language'] = 'English'

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387       9984670  0.913   America  English
# France              63.951   2833687        640679  0.888    Europe  English
# Germany             80.940   3874437        357114  0.916    Europe  English
# Italy               60.665   2167744        301336  0.873    Europe  English
# Japan              127.061   4602367        377930  0.891      Asia  English
# United Kingdom      64.511   2950039        242495  0.907    Europe  English
# United States      318.523  17348075       9525067  0.915   America  English

# %% [markdown]
# ---
# ### Renaming Columns

# %%
df
# Out:
#                 Population  Gross_Domestic_Product  Surface_Area    HDI  \
# Canada             135.467                 1785387       9984670  0.913
# France             163.951                 2833687        640679  0.888
# Germany            180.940                 3874437        357114  0.916
# Italy              160.665                 2167744        301336  0.873
# Japan              227.061                 4602367        377930  0.891
# United Kingdom     164.511                 2950039        242495  0.907
# United States      418.523                17348075       9525067  0.915
#
#                Continent Language
# Canada           America  English
# France            Europe  English
# Germany           Europe  English
# Italy             Europe  English
# Japan               Asia  English
# United Kingdom    Europe  English
# United States    America  English

# %%
df.rename(columns = {
    "Gross_Domestic_Product" : "GDP",
    "Surface_Area" : "Surface Area"
}, index = {
    "United Kingdom" : "UK",
    "United States" : "US"
},inplace = True
)

# %%
df
# Out:
#          Population       GDP  Surface Area    HDI Continent Language
# Canada      135.467   1785387       9984670  0.913   America  English
# France      163.951   2833687        640679  0.888    Europe  English
# Germany     180.940   3874437        357114  0.916    Europe  English
# Italy       160.665   2167744        301336  0.873    Europe  English
# Japan       227.061   4602367        377930  0.891      Asia  English
# UK          164.511   2950039        242495  0.907    Europe  English
# US          418.523  17348075       9525067  0.915   America  English

# %%
df.rename(columns = {
    "Surface Area" : "Surface_Area",
    "GDP" : "Gross_Domestic_Product"
}, inplace = True)

# %%
df.rename(
    columns={
        'HDI': 'Human Development Index',
        'Anual Popcorn Consumption': 'APC'
    }, index={
        'United States': 'USA',
        'United Kingdom': 'UK',
        'Argentina': 'AR'
    })
# Out:
#          Population       GDP  Surface Area  Human Development Index  \
# Canada       35.467   1785387       9984670                    0.913
# France       63.951   2833687        640679                    0.888
# Germany      80.940   3874437        357114                    0.916
# Italy        60.665   2167744        301336                    0.873
# Japan       127.061   4602367        377930                    0.891
# UK           64.511   2950039        242495                    0.907
# USA         318.523  17348075       9525067                    0.915
#
#         Continent Language
# Canada    America  English
# France     Europe  English
# Germany    Europe  English
# Italy      Europe  English
# Japan        Asia  English
# UK         Europe  English
# USA       America  English

# %%
s = "TEST"
s.lower()
# Out:
# 'test'

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'UK', 'US'], dtype='object')

# %%
df.rename(index=str.lower)

# %%
df.rename(index=str.upper)
# Out:
#          Population       GDP  Surface Area    HDI Continent Language
# CANADA      135.467   1785387       9984670  0.913   America  English
# FRANCE      163.951   2833687        640679  0.888    Europe  English
# GERMANY     180.940   3874437        357114  0.916    Europe  English
# ITALY       160.665   2167744        301336  0.873    Europe  English
# JAPAN       227.061   4602367        377930  0.891      Asia  English
# UK          164.511   2950039        242495  0.907    Europe  English
# US          418.523  17348075       9525067  0.915   America  English

# %%
df.rename(index = lambda x: x.upper())
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# CANADA              35.467   1785387       9984670  0.913   America
# FRANCE              63.951   2833687        640679  0.888    Europe
# GERMANY             80.940   3874437        357114  0.916    Europe
# ITALY               60.665   2167744        301336  0.873    Europe
# JAPAN              127.061   4602367        377930  0.891      Asia
# UNITED KINGDOM      64.511   2950039        242495  0.907    Europe
# UNITED STATES      318.523  17348075       9525067  0.915   America

# %%
small_case = [index.lower() for index in df.index]

# %%
df.rename(index = small_case)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-bdd6d30959c6> in <module>
# ----> 1 df.rename(index = small_case)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     322         @wraps(func)
#     323         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 324             return func(*args, **kwargs)
#     325
#     326         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5037         4  3  6
#    5038         """
# -> 5039         return super().rename(
#    5040             mapper=mapper,
#    5041             index=index,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1154                     raise KeyError(f"{missing_labels} not found in axis")
#    1155
# -> 1156             new_index = ax._transform_index(f, level)
#    1157             result._set_axis_nocheck(new_index, axis=axis_no, inplace=True)
#    1158             result._clear_item_cache()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in _transform_index(self, func, level)
#    5544             return type(self).from_tuples(items, names=self.names)
#    5545         else:
# -> 5546             items = [func(x) for x in self]
#    5547             return Index(items, name=self.name, tupleize_cols=False)
#    5548
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in <listcomp>(.0)
#    5544             return type(self).from_tuples(items, names=self.names)
#    5545         else:
# -> 5546             items = [func(x) for x in self]
#    5547             return Index(items, name=self.name, tupleize_cols=False)
#    5548
#
# TypeError: 'list' object is not callable

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.rename(index=lambda x: x.lower())
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# canada              35.467   1785387       9984670  0.913   America  English
# france              63.951   2833687        640679  0.888    Europe  English
# germany             80.940   3874437        357114  0.916    Europe  English
# italy               60.665   2167744        301336  0.873    Europe  English
# japan              127.061   4602367        377930  0.891      Asia  English
# united kingdom      64.511   2950039        242495  0.907    Europe  English
# united states      318.523  17348075       9525067  0.915   America  English

# %% [markdown]
# ---
# ### Dropping columns

# %%
df["Language"] = "Hindi"

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387       9984670  0.913   America    Hindi
# France              63.951   2833687        640679  0.888    Europe    Hindi
# Germany             80.940   3874437        357114  0.916    Europe    Hindi
# Italy               60.665   2167744        301336  0.873    Europe    Hindi
# Japan              127.061   4602367        377930  0.891      Asia    Hindi
# United Kingdom      64.511   2950039        242495  0.907    Europe    Hindi
# United States      318.523  17348075       9525067  0.915   America    Hindi

# %%
df.drop(columns = ["Language"], inplace = True)

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(columns='Language', inplace=True)

# %% [markdown]
# ---
# ### Adding values

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df = df.append(pd.Series({
    "Population" : 1400,
    "GDP" : 2500000,
    "Continent" : "Asia"
}, name  = "India"))

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387     9984670.0  0.913   America
# France              63.951   2833687      640679.0  0.888    Europe
# Germany             80.940   3874437      357114.0  0.916    Europe
# Italy               60.665   2167744      301336.0  0.873    Europe
# Japan              127.061   4602367      377930.0  0.891      Asia
# United Kingdom      64.511   2950039      242495.0  0.907    Europe
# United States      318.523  17348075     9525067.0  0.915   America
# India             1400.000   2500000           NaN    NaN      Asia

# %%
df.append(pd.Series({
    'Population': 3,
    'GDP': 5
}, name='China'))
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# Canada              35.467   1785387.0     9984670.0  0.913   America
# France              63.951   2833687.0      640679.0  0.888    Europe
# Germany             80.940   3874437.0      357114.0  0.916    Europe
# Italy               60.665   2167744.0      301336.0  0.873    Europe
# Japan              127.061   4602367.0      377930.0  0.891      Asia
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe
# United States      318.523  17348075.0     9525067.0  0.915   America
# China                3.000         5.0           NaN    NaN       NaN

# %% [markdown]
# Append returns a new `DataFrame`:

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# You can directly set the new index and values to the `DataFrame`:

# %%
df.loc['China'] = pd.Series({'Population': 1_400_000_000, 'Continent': 'Asia'})

# %%
df.loc["Pakistan"] = pd.Series([50000,2000, 43234, 0.34, "Asia" ], index = ["Population", "GDP", "Surface Area","HDI", "Continent"])
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# India           1.400000e+03   2500000.0           NaN    NaN      Asia
# China           1.400000e+09         NaN           NaN    NaN      Asia
# Pakistan        5.000000e+04      2000.0       43234.0  0.340      Asia

# %%
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# India           1.400000e+03   2500000.0           NaN    NaN      Asia
# China           1.400000e+09         NaN           NaN    NaN      Asia

# %% [markdown]
# We can use `drop` to just remove a row by index:

# %%
df.drop('China', inplace=True)

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent
# Canada              35.467   1785387.0     9984670.0  0.913   America
# France              63.951   2833687.0      640679.0  0.888    Europe
# Germany             80.940   3874437.0      357114.0  0.916    Europe
# Italy               60.665   2167744.0      301336.0  0.873    Europe
# Japan              127.061   4602367.0      377930.0  0.891      Asia
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe
# United States      318.523  17348075.0     9525067.0  0.915   America

# %% [markdown]
# ---
# ### More radical index changes

# %%
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# India           1.400000e+03   2500000.0           NaN    NaN      Asia
# China           1.400000e+09         NaN           NaN    NaN      Asia
# Pakistan        5.000000e+04      2000.0       43234.0  0.340      Asia

# %%
df.reset_index(drop = True)
# Out:
#      Population         GDP  Surface Area    HDI Continent
# 0  3.546700e+01   1785387.0     9984670.0  0.913   America
# 1  6.395100e+01   2833687.0      640679.0  0.888    Europe
# 2  8.094000e+01   3874437.0      357114.0  0.916    Europe
# 3  6.066500e+01   2167744.0      301336.0  0.873    Europe
# 4  1.270610e+02   4602367.0      377930.0  0.891      Asia
# 5  6.451100e+01   2950039.0      242495.0  0.907    Europe
# 6  3.185230e+02  17348075.0     9525067.0  0.915   America
# 7  1.400000e+03   2500000.0           NaN    NaN      Asia
# 8  1.400000e+09         NaN           NaN    NaN      Asia
# 9  5.000000e+04      2000.0       43234.0  0.340      Asia

# %%
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# India           1.400000e+03   2500000.0           NaN    NaN      Asia
# China           1.400000e+09         NaN           NaN    NaN      Asia
# Pakistan        5.000000e+04      2000.0       43234.0  0.340      Asia

# %%
df.set_index('Population')
# Out:
#                      GDP  Surface Area    HDI Continent
# Population
# 3.546700e+01   1785387.0     9984670.0  0.913   America
# 6.395100e+01   2833687.0      640679.0  0.888    Europe
# 8.094000e+01   3874437.0      357114.0  0.916    Europe
# 6.066500e+01   2167744.0      301336.0  0.873    Europe
# 1.270610e+02   4602367.0      377930.0  0.891      Asia
# 6.451100e+01   2950039.0      242495.0  0.907    Europe
# 3.185230e+02  17348075.0     9525067.0  0.915   America
# 1.400000e+03   2500000.0           NaN    NaN      Asia
# 1.400000e+09         NaN           NaN    NaN      Asia
# 5.000000e+04      2000.0       43234.0  0.340      Asia

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Creating columns from other columns
#
# Altering a DataFrame often involves combining different columns into another. For example, in our Countries analysis, we could try to calculate the "GDP per capita", which is just, `GDP / Population`.

# %%
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# India           1.400000e+03   2500000.0           NaN    NaN      Asia
# China           1.400000e+09         NaN           NaN    NaN      Asia
# Pakistan        5.000000e+04      2000.0       43234.0  0.340      Asia

# %%
df["GDP_per_capita"] = df["GDP"] / df["Population"]

# %%
df
# Out:
#                   Population         GDP  Surface Area    HDI Continent  \
# Canada          3.546700e+01   1785387.0     9984670.0  0.913   America
# France          6.395100e+01   2833687.0      640679.0  0.888    Europe
# Germany         8.094000e+01   3874437.0      357114.0  0.916    Europe
# Italy           6.066500e+01   2167744.0      301336.0  0.873    Europe
# Japan           1.270610e+02   4602367.0      377930.0  0.891      Asia
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# India           1.400000e+03   2500000.0           NaN    NaN      Asia
# China           1.400000e+09         NaN           NaN    NaN      Asia
# Pakistan        5.000000e+04      2000.0       43234.0  0.340      Asia
#
#                 GDP_per_capita
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330
# India              1785.714286
# China                      NaN
# Pakistan              0.040000

# %%
df[['Population', 'GDP']]
# Out:
#                 Population         GDP
# Canada              35.467   1785387.0
# France              63.951   2833687.0
# Germany             80.940   3874437.0
# Italy               60.665   2167744.0
# Japan              127.061   4602367.0
# United Kingdom      64.511   2950039.0
# United States      318.523  17348075.0

# %% [markdown]
# The regular pandas way of expressing that, is just dividing each series:

# %%
df['GDP'] / df['Population']
# Out:
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330
# dtype: float64

# %% [markdown]
# The result of that operation is just another series that you can add to the original `DataFrame`:

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#                 Population         GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387.0     9984670.0  0.913   America
# France              63.951   2833687.0      640679.0  0.888    Europe
# Germany             80.940   3874437.0      357114.0  0.916    Europe
# Italy               60.665   2167744.0      301336.0  0.873    Europe
# Japan              127.061   4602367.0      377930.0  0.891      Asia
# United Kingdom      64.511   2950039.0      242495.0  0.907    Europe
# United States      318.523  17348075.0     9525067.0  0.915   America
#
#                 GDP Per Capita
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Statistical info
#
# You've already seen the `describe` method, which gives you a good "summary" of the `DataFrame`. Let's explore other methods in more detail:

# %%
df.head()
# Out:
#          Population        GDP  Surface Area    HDI Continent  GDP_per_capita
# Canada       35.467  1785387.0     9984670.0  0.913   America    50339.385908
# France       63.951  2833687.0      640679.0  0.888    Europe    44310.284437
# Germany      80.940  3874437.0      357114.0  0.916    Europe    47868.013343
# Italy        60.665  2167744.0      301336.0  0.873    Europe    35733.025633
# Japan       127.061  4602367.0      377930.0  0.891      Asia    36221.712406

# %%
df.tail()
# Out:
#                   Population         GDP  Surface Area    HDI Continent  \
# United Kingdom  6.451100e+01   2950039.0      242495.0  0.907    Europe
# United States   3.185230e+02  17348075.0     9525067.0  0.915   America
# India           1.400000e+03   2500000.0           NaN    NaN      Asia
# China           1.400000e+09         NaN           NaN    NaN      Asia
# Pakistan        5.000000e+04      2000.0       43234.0  0.340      Asia
#
#                 GDP_per_capita
# United Kingdom    45729.239975
# United States     54464.120330
# India              1785.714286
# China                      NaN
# Pakistan              0.040000

# %%
df.head()
# Out:
#          Population        GDP  Surface Area    HDI Continent  GDP Per Capita
# Canada       35.467  1785387.0     9984670.0  0.913   America    50339.385908
# France       63.951  2833687.0      640679.0  0.888    Europe    44310.284437
# Germany      80.940  3874437.0      357114.0  0.916    Europe    47868.013343
# Italy        60.665  2167744.0      301336.0  0.873    Europe    35733.025633
# Japan       127.061  4602367.0      377930.0  0.891      Asia    36221.712406

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI  GDP Per Capita
# count    7.000000  7.000000e+00  7.000000e+00  7.000000        7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429    44952.254576
# std     97.249970  5.494020e+06  4.576187e+06  0.016592     6954.983875
# min     35.467000  1.785387e+06  2.424950e+05  0.873000    35733.025633
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500    40265.998421
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000    45729.239975
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000    49103.699626
# max    318.523000  1.734808e+07  9.984670e+06  0.916000    54464.120330

# %%
population = df['Population']

# %%
type(population)
# Out:
# pandas.core.series.Series

# %%
population.min(), population.max()
# Out:
# (35.467, 318.523)

# %%
df["Population"].min(), df["Population"].max()
# Out:
# (35.467, 1400000000.0)

# %%
df["Population"]
# Out:
# Canada            3.546700e+01
# France            6.395100e+01
# Germany           8.094000e+01
# Italy             6.066500e+01
# Japan             1.270610e+02
# United Kingdom    6.451100e+01
# United States     3.185230e+02
# India             1.400000e+03
# China             1.400000e+09
# Pakistan          5.000000e+04
# Name: Population, dtype: float64

# %%
df["Population"].sum() / len(df["Population"])
# Out:
# 140005215.11180001

# %%
population.sum()
# Out:
# 751.118

# %%
population.sum() / len(population)
# Out:
# 107.30257142857144

# %%
population.mean()
# Out:
# 107.30257142857144

# %%
population.std()
# Out:
# 97.24996987121581

# %%
population.median()
# Out:
# 64.511

# %%
population.describe()
# Out:
# count      7.000000
# mean     107.302571
# std       97.249970
# min       35.467000
# 25%       62.308000
# 50%       64.511000
# 75%      104.000500
# max      318.523000
# Name: Population, dtype: float64

# %%
population.quantile(.25)
# Out:
# 62.308

# %%
df["Population"].quantile(.75)
# Out:
# 1129.63075

# %%
population.quantile([.2, .4, .6, .8, 1])
# Out:
# 0.2     61.3222
# 0.4     64.1750
# 0.6     74.3684
# 0.8    117.8368
# 1.0    318.5230
# Name: Population, dtype: float64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
