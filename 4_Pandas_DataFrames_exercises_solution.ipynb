# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham62025865/shubham1/blob/main/4_Pandas_DataFrames_exercises_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.3.5

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       NaN
# NaN  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
pd.DataFrame(data =marvel_data )
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# your code goes here
marvel_df.columns = ['name', 'sex', 'first_appearance']
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
marvel_df.head()
# Out:
#               name   sex  first_appearance
# 0       Spider-Man  male              1962
# 1  Captain America  male              1941
# 2        Wolverine  male              1974
# 3         Iron Man  male              1963
# 4             Thor  male              1963

# %%
marvel_df.index = marvel_df.name

# %%
marvel_df.head()
# Out:
#                             name   sex  first_appearance
# name
# Spider-Man            Spider-Man  male              1962
# Captain America  Captain America  male              1941
# Wolverine              Wolverine  male              1974
# Iron Man                Iron Man  male              1963
# Thor                        Thor  male              1963

# %%
marvel_df.set_index("name", inplace = True)

# %%
marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
marvel_df.reset_index()
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
# your code goes here
marvel_df.index = marvel_df["name"]
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
marvel_df.set_index('name', inplace = True)

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df.drop(columns = ["name"], inplace = True)
marvel_df = marvel_df.drop(columns = ["name"])
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
marvel_df.drop(index = ["Namor", "Hank Pym"])
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
# your code goes here
marvel_df.drop(['Namor', 'Hank Pym'])
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# ...

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()
# Out:
#                   sex  first_appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
marvel_df.iloc[-5:,]
#marvel_df.tail()
# Out:
#                    sex  first_appearance
# name
# Doctor Strange    male              1963
# Scarlet Witch   female              1964
# Wasp            female              1963
# Black Widow     female              1964
# Vision            male              1968

# %%
marvel_df.iloc[0:6,[1]]
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male
# Thing            male

# %%
marvel_df.sex.head()
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %%
marvel_df['sex'].head()
# Out:
# name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here

# %%
#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
a = "test"
a[0:4]
# Out:
# 'test'

# %%
marvel_df.first_appearance[1:-1]
# Out:
# name
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Hank Pym            1962
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Name: first_appearance, dtype: int64

# %%
# your code goes here
marvel_df.iloc[1:-1]["first_appearance"]
# Out:
# name
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Hank Pym            1962
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Name: first_appearance, dtype: int64

# %%
marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
marvel_df.iloc[1:-1,:].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Namor                         1939
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Hank Pym                      1962
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()
# Out:
#                   first_appearance
# name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_df.iloc[[0,-1],:]
# Out:
#                   name   sex  first_appearance
# name
# Spider-Man  Spider-Man  male              1962
# Vision          Vision  male              1968

# %%
marvel_df.iloc[0: :len(marvel_df) -1]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
marvel_df.iloc[[0,-1]]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %%
# print(marvel_df.head(1), marvel_df.tail(1))
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962          sex  first_appearance
# name
# Vision  male              1968

# %%
marvel_df[(marvel_df.index == 0) | (marvel_df.index == (len(marvel_df)-1)]
# Out:
# Empty DataFrame
# Columns: [name, sex, first_appearance]
# Index: []

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
# your code goes here
marvel_df.loc[0:len(marvel_df): 2]
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 2          Wolverine    male              1974
# 4               Thor    male              1963
# 6   Mister Fantastic    male              1961
# 8              Beast    male              1963
# 10             Storm  female              1975
# 12           Hawkeye    male              1964
# 14    Doctor Strange    male              1963
# 16     Scarlet Witch  female              1964
# 18       Black Widow  female              1964

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]
# Out:
#              sex  first_appearance
# name
# Spider-Man  male              1962
# Vision      male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here

# %%
marvel_df.loc["Vision", "first_appearance"] = 1964

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1964

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964

marvel_df
# Out:
#                               name     sex  first_appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here

# %%
marvel_df['years_since'] = 2022 - marvel_df['first_appearance']

marvel_df
# Out:
#                               name     sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man    male              1962           60
# Captain America    Captain America    male              1941           81
# Wolverine                Wolverine    male              1974           48
# Iron Man                  Iron Man    male              1963           59
# Thor                          Thor    male              1963           59
# Thing                        Thing    male              1961           61
# Mister Fantastic  Mister Fantastic    male              1961           61
# Hulk                          Hulk    male              1962           60
# Beast                        Beast    male              1963           59
# Invisible Woman    Invisible Woman  female              1961           61
# Storm                        Storm  female              1975           47
# Namor                        Namor    male              1939           83
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %%
marvel_df.head()
# Out:
#                             name   sex  first_appearance  years_since
# name
# Spider-Man            Spider-Man  male              1962           60
# Captain America  Captain America  male              1941           81
# Wolverine              Wolverine  male              1974           48
# Iron Man                Iron Man  male              1963           59
# Thor                        Thor  male              1963           59

# %%
marvel_df[marvel_df["sex"] == "male"]
# Out:
#                               name   sex  first_appearance  years_since
# name
# Spider-Man              Spider-Man  male              1962           60
# Captain America    Captain America  male              1941           81
# Wolverine                Wolverine  male              1974           48
# Iron Man                  Iron Man  male              1963           59
# Thor                          Thor  male              1963           59
# Thing                        Thing  male              1961           61
# Mister Fantastic  Mister Fantastic  male              1961           61
# Hulk                          Hulk  male              1962           60
# Beast                        Beast  male              1963           59
# Namor                        Namor  male              1939           83
# Hawkeye                    Hawkeye  male              1964           58
# Daredevil                Daredevil  male              1964           58
# ...

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here

# %%
mask = marvel_df['sex'] == 'female'

mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here

# %%
mask = marvel_df['sex'] == 'male'

marvel_df[mask]
# Out:
#                    sex  first_appearance  years_since
# name
# Spider-Man        male              1962           56
# Captain America   male              1941           77
# Wolverine         male              1974           44
# Iron Man          male              1963           55
# Thor              male              1963           55
# Thing             male              1961           57
# Mister Fantastic  male              1961           57
# Hulk              male              1962           56
# Beast             male              1963           55
# Hawkeye           male              1964           54
# Daredevil         male              1964           54
# Doctor Strange    male              1963           55
# Vision            male              1964           54

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here

# %%
mask = marvel_df['first_appearance'] > 1965

marvel_df[mask]
# Out:
#          name     sex  first_appearance
# 2   Wolverine    male              1974
# 10      Storm  female              1975
# 19     Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]
# Out:
#           sex  first_appearance  years_since
# name
# Storm  female              1975           43

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here

# %%
marvel_df.describe()
# Out:
#        first_appearance
# count         20.000000
# mean        1961.850000
# std            8.405982
# min         1939.000000
# 25%         1961.750000
# 50%         1963.000000
# 75%         1964.000000
# max         1975.000000

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here

# %%
#np.mean(marvel_df.first_appearance)
marvel_df.first_appearance.mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()
# Out:
# 1939

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
marvel_df
# Out:
#                      sex  first_appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1964

# %%
marvel_df.first_appearance.min()
# Out:
# 1939

# %%
marvel_df.first_appearance == marvel_df.first_appearance.min()
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm               False
# Namor                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# Name: first_appearance, dtype: bool

# %%
marvel_df[marvel_df.first_appearance == marvel_df.first_appearance.min()].index.values[0]
# Out:
# 'Namor'

# %%
marvel_df.index[marvel_df.first_appearance == marvel_df.first_appearance.min()].values[0]
# Out:
# 'Namor'

# %%
marvel_df.first_appearance.min()
# Out:
# 1939

# %%
marvel_df.first_appearance == marvel_df.first_appearance.min()
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm               False
# Namor                True
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# Name: first_appearance, dtype: bool

# %%
# your code goes here
marvel_df[marvel_df.first_appearance == marvel_df.first_appearance.min()]
# Out:
#      name   sex  first_appearance
# 11  Namor  male              1939

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#                   sex  first_appearance  years_since
# name
# Captain America  male              1941           77

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#                 name     sex  first_appearance  years_since
# 0         Spider-Man    male              1962           56
# 1    Captain America    male              1941           77
# 2          Wolverine    male              1974           44
# 3           Iron Man    male              1963           55
# 4               Thor    male              1963           55
# 5              Thing    male              1961           57
# 6   Mister Fantastic    male              1961           57
# 7               Hulk    male              1962           56
# 8              Beast    male              1963           55
# 9    Invisible Woman  female              1961           57
# 10             Storm  female              1975           43
# 11           Hawkeye    male              1964           54
# 12         Daredevil    male              1964           54
# 13    Doctor Strange    male              1963           55
# 14     Scarlet Witch  female              1964           54
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  3., 12.,  0.,  0.,  2.]),
#  array([1941. , 1944.4, 1947.8, 1951.2, 1954.6, 1958. , 1961.4, 1964.8,
#         1968.2, 1971.6, 1975. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
