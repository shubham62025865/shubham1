# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham62025865/shubham1/blob/main/NBADataSetWorks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df_nba = pd.read_csv("/content/nba.csv")
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
type(df_nba)
# Out:
# pandas.core.frame.DataFrame

# %%
df_nba.size
# Out:
# 4113

# %%
df_nba.shape
# Out:
# (457, 9)

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df_nba.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df_nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df_nba.sort_values(by = ["Name"], ascending = True)
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 152     Aaron Brooks           Chicago Bulls       0       PG   31    6-0
# 356     Aaron Gordon           Orlando Magic       0       PF   20  06-09
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21  06-06
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25  06-10
# 312       Al Horford           Atlanta Hawks      15        C   30  06-10
# ..               ...                     ...     ...      ...  ...    ...
# 386  Wilson Chandler          Denver Nuggets      21       SF   29  06-08
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24  06-03
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21  06-05
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34  06-09
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32  06-11
#
#      Weight         College      Salary
# ...

# %%
df_nba.sort_values(by=["Team"],ascending=True)
# Out:
#                  Name                Team  Number Position  Age Height  \
# 317   Lamar Patterson       Atlanta Hawks      13       SG   24  06-05
# 309     Kent Bazemore       Atlanta Hawks      24       SF   26  06-05
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24  06-06
# 311      Kirk Hinrich       Atlanta Hawks      12       SG   35  06-04
# 312        Al Horford       Atlanta Hawks      15        C   30  06-10
# ..                ...                 ...     ...      ...  ...    ...
# 371      Jarell Eddie  Washington Wizards       8       SG   24  06-07
# 369      Bradley Beal  Washington Wizards       3       SG   22  06-05
# 368     Alan Anderson  Washington Wizards       6       SG   33  06-06
# 382         John Wall  Washington Wizards       2       PG   25  06-04
# 370      Jared Dudley  Washington Wizards       1       SF   30  06-07
#
#      Weight         College      Salary
# 317     225      Pittsburgh    525093.0
# ...

# %%
df_nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2   John Holland  Boston Celtics      30       SG   27  06-05     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df_nba.sort_values(by=["Team","Salary"],ascending=True)
# Out:
#                  Name                Team  Number Position  Age Height  \
# 317   Lamar Patterson       Atlanta Hawks      13       SG   24  06-05
# 316      Mike Muscala       Atlanta Hawks      31       PF   24  06-11
# 313    Kris Humphries       Atlanta Hawks      43       PF   31  06-09
# 322    Walter Tavares       Atlanta Hawks      22        C   24  07-03
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24  06-06
# ..                ...                 ...     ...      ...  ...    ...
# 369      Bradley Beal  Washington Wizards       3       SG   22  06-05
# 376   Markieff Morris  Washington Wizards       5       PF   26  06-10
# 373     Marcin Gortat  Washington Wizards      13        C   32  06-11
# 375      Nene Hilario  Washington Wizards      42        C   33  06-11
# 382         John Wall  Washington Wizards       2       PG   25  06-04
#
#      Weight     College      Salary
# 317     225  Pittsburgh    525093.0
# 316     240    Bucknell    947276.0
# ...

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_nba.Team.value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_nba.Position.value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: count, dtype: int64

# %%
df_nba[["College","Team"]].value_counts()
# Out:
# College         Team
# Kentucky        Phoenix Suns              4
# North Carolina  Memphis Grizzlies         3
# Duke            Miami Heat                3
# UCLA            Memphis Grizzlies         3
# Kentucky        Sacramento Kings          3
#                                          ..
# Kansas          Philadelphia 76ers        1
#                 Oklahoma City Thunder     1
#                 Minnesota Timberwolves    1
#                 Los Angeles Lakers        1
# Xavier          San Antonio Spurs         1
# Name: count, Length: 336, dtype: int64

# %%
df_nba[["Name","Salary"]].value_counts()
# Out:
# Name                 Salary
# Aaron Brooks         2250000.0     1
# Matthew Dellavedova  1147276.0     1
# Mike Scott           3333333.0     1
# Mike Muscala         947276.0      1
# Mike Miller          947276.0      1
#                                   ..
# Greivis Vasquez      6600000.0     1
# Greg Monroe          16407500.0    1
# Gorgui Dieng         1474440.0     1
# Gordon Hayward       15409570.0    1
# Zaza Pachulia        5200000.0     1
# Name: count, Length: 446, dtype: int64

# %%
df_nba[["Age","Height","Weight"]].value_counts()
# Out:
# Age  Height  Weight
# 27   06-03   200       4
# 29   06-08   230       3
# 30   06-05   210       3
# 23   06-06   205       3
# 24   06-03   190       3
#                       ..
# 25   06-04   194       1
#      06-03   195       1
#              175       1
#      06-02   185       1
# 40   06-11   250       1
# Name: count, Length: 418, dtype: int64

# %%
df_nba.Name.unique()
# Out:
# array(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#        'Jonas Jerebko', 'Amir Johnson', 'Jordan Mickey', 'Kelly Olynyk',
#        'Terry Rozier', 'Marcus Smart', 'Jared Sullinger', 'Isaiah Thomas',
#        'Evan Turner', 'James Young', 'Tyler Zeller', 'Bojan Bogdanovic',
#        'Markel Brown', 'Wayne Ellington', 'Rondae Hollis-Jefferson',
#        'Jarrett Jack', 'Sergey Karasev', 'Sean Kilpatrick',
#        'Shane Larkin', 'Brook Lopez', 'Chris McCullough', 'Willie Reed',
#        'Thomas Robinson', 'Henry Sims', 'Donald Sloan', 'Thaddeus Young',
#        'Arron Afflalo', 'Lou Amundson', 'Thanasis Antetokounmpo',
#        'Carmelo Anthony', 'Jose Calderon', 'Cleanthony Early',
#        'Langston Galloway', 'Jerian Grant', 'Robin Lopez', "Kyle O'Quinn",
#        'Kristaps Porzingis', 'Kevin Seraphin', 'Lance Thomas',
#        'Sasha Vujacic', 'Derrick Williams', 'Tony Wroten', 'Elton Brand',
# ...

# %%
df_nba[df_nba["Team"] == "Boston Celtics"]
# Out:
#                Name            Team  Number Position  Age Height  Weight  \
# 0     Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1       Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2      John Holland  Boston Celtics      30       SG   27  06-05     205
# 3       R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4     Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# 5      Amir Johnson  Boston Celtics      90       PF   29  06-09     240
# 6     Jordan Mickey  Boston Celtics      55       PF   21  06-08     235
# 7      Kelly Olynyk  Boston Celtics      41        C   25    7-0     238
# 8      Terry Rozier  Boston Celtics      12       PG   22  06-02     190
# 9      Marcus Smart  Boston Celtics      36       PG   22  06-04     220
# 10  Jared Sullinger  Boston Celtics       7        C   24  06-09     260
# 11    Isaiah Thomas  Boston Celtics       4       PG   27  05-09     185
# ...

# %%
df_nba[df_nba["Name"]=="Avery Bradley"]
# Out:
#             Name            Team  Number Position  Age Height  Weight College  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-02     180   Texas
#
#       Salary
# 0  7730337.0

# %%
df_nba[df_nba["College"]=="Kentucky"]
# Out:
#                        Name                    Team  Number Position  Age  \
# 13              James Young          Boston Celtics      13       SG   20
# 55             Nerlens Noel      Philadelphia 76ers       4       PF   22
# 69        Patrick Patterson         Toronto Raptors      54       PF   27
# 115           Julius Randle      Los Angeles Lakers      30       PF   21
# 121            Eric Bledsoe            Phoenix Suns       2       PG   26
# 122            Devin Booker            Phoenix Suns       1       SG   19
# 125          Archie Goodwin            Phoenix Suns      20       SG   21
# 127          Brandon Knight            Phoenix Suns       3       PG   24
# 141     Willie Cauley-Stein        Sacramento Kings       0        C   22
# 143        DeMarcus Cousins        Sacramento Kings      15        C   25
# 150             Rajon Rondo        Sacramento Kings       9       PG   30
# 193             Jodie Meeks         Detroit Pistons      20       SG   28
# ...

# %%
temp_df = df_nba.copy()
temp_df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
temp_df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
salary_mean = temp_df["Salary"].mean()

# %%
salary_mean
# Out:
# 4842684.105381166

# %%
temp_df["Salary"].fillna(value=salary_mean,inplace=True)
# Out:
# <ipython-input-29-41321aa8d388>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   temp_df["Salary"].fillna(value=salary_mean,inplace=True)

# %%
temp_df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %%
df_nba.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df_nba["Salary"].fillna(value=4842684.105381166,inplace=True)
# Out:
# <ipython-input-32-5c076eafedea>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_nba["Salary"].fillna(value=4842684.105381166,inplace=True)

# %%
df_nba.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %%
df_nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-02     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-06     235
# 2     John Holland  Boston Celtics      30       SG   27  06-05     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-05     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  06-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-03     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-01     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-03     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
df_nba["College"].fillna(value="sityog",inplace=True)
# Out:
# <ipython-input-35-7d928b775b0a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_nba["College"].fillna(value="sityog",inplace=True)

# %%
df_nba.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df_nba.groupby("College")[["Age","Name"]].min()
# Out:
#                Age              Name
# College
# Alabama         25        Alonzo Gee
# Arizona         20      Aaron Gordon
# Arizona State   26      James Harden
# Arkansas        21      Bobby Portis
# Baylor          25        Quincy Acy
# ...            ...               ...
# Wichita State   25  Cleanthony Early
# Wisconsin       22      Devin Harris
# Wyoming         23   Larry Nance Jr.
# Xavier          35        David West
# sityog          20      Al Jefferson
#
# [119 rows x 2 columns]

# %%
df_nba.groupby("Team")["Salary"].max()
# Out:
# Team
# Atlanta Hawks             18671659.0
# Boston Celtics            12000000.0
# Brooklyn Nets             19689000.0
# Charlotte Hornets         13500000.0
# Chicago Bulls             20093064.0
# Cleveland Cavaliers       22970500.0
# Dallas Mavericks          16407500.0
# Denver Nuggets            14000000.0
# Detroit Pistons           16000000.0
# Golden State Warriors     15501000.0
# Houston Rockets           22359364.0
# Indiana Pacers            17120106.0
# Los Angeles Clippers      21468695.0
# Los Angeles Lakers        25000000.0
# Memphis Grizzlies         19688000.0
# Miami Heat                22192730.0
# Milwaukee Bucks           16407500.0
# Minnesota Timberwolves    12700000.0
# New Orleans Pelicans      15514031.0
# New York Knicks           22875000.0
# Oklahoma City Thunder     20158622.0
# Orlando Magic             11250000.0
# Philadelphia 76ers         6500000.0
# Phoenix Suns              13500000.0
# Portland Trail Blazers     8042895.0
# ...
